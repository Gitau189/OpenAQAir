# %% [markdown]
# # OpenAQ Air Quality Analysis
# ## Introduction
# <text>

# %% [markdown]
# ## Prerequisite Packages Installation

# %%
! pip install requests
! pip install pandas
! pip install matplotlib
! pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /home/misti/.local/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/misti/.local/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/misti/.local/lib/python3.10/site-packages (from requests) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/misti/.local/lib/python3.10/site-packages (from requests) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/misti/.local/lib/python3.10/site-packages (from requests) (2024.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/misti/.local/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/misti/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /home/misti/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/misti/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/misti/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/misti/.local/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: pillow>=8 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: numpy<2,>=1.21 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/misti/.local/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/misti/.local/lib/python3.10/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: pandas>=1.2 in /home/misti/.local/lib/python3.10/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/misti/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/misti/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /home/misti/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %% [markdown]
# ## Module Importation

# %%
import requests
import pandas as pd
from time import sleep
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from random import choice
from matplotlib.lines import Line2D

# %% [markdown]
# ## Data Retrieval
# The `read_csv()` function is used to obtain data from the ./data/ folder. Moreover, unnecessary columns are dropped to facilitate ease of interpretation.

# %%
df_lublin = pd.read_csv("./data/Lublin_20_February_2024_to_20_March_2024.csv")
df_malkia = pd.read_csv("./data/Malkia_Nakuru_20_February_2024_to_20_March_2024.csv")
df_nyayo = pd.read_csv("./data/Nyayo_Embakasi_Nairobi_20_February_2024_to_20_March_2024.csv")
df_ogada = pd.read_csv("./data/Ogada_Obubra_20_February_2024_to_20_March_2024.csv")

df_lublin.drop(['latitude', 'longitude', 'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider', 'datetimeLocal'], axis=1, inplace=True)
df_malkia.drop(['latitude', 'longitude', 'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider', 'datetimeLocal'], axis=1, inplace=True)
df_nyayo.drop(['latitude', 'longitude', 'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider', 'datetimeLocal'], axis=1, inplace=True)
df_ogada.drop(['latitude', 'longitude', 'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider', 'datetimeLocal'], axis=1, inplace=True)

# %%
df_lublin.head(5)
# Out:
#    location_id            location_name parameter  value   unit  \
# 0        10528  Lublin, ul. Obywatelska        co  210.0  µg/m³
# 1        10528  Lublin, ul. Obywatelska        co  190.0  µg/m³
# 2        10528  Lublin, ul. Obywatelska        co  180.0  µg/m³
# 3        10528  Lublin, ul. Obywatelska        co  190.0  µg/m³
# 4        10528  Lublin, ul. Obywatelska        co  190.0  µg/m³
#
#                  datetimeUtc       timezone
# 0  2024-02-20T01:00:00+00:00  Europe/Warsaw
# 1  2024-02-20T02:00:00+00:00  Europe/Warsaw
# 2  2024-02-20T03:00:00+00:00  Europe/Warsaw
# 3  2024-02-20T04:00:00+00:00  Europe/Warsaw
# 4  2024-02-20T05:00:00+00:00  Europe/Warsaw

# %%
df_malkia.head(5)
# Out:
#    location_id                          location_name parameter  value   unit  \
# 0      1894637  Malkia, Nakuru (DBUSY3473 → ATQJXRNT)      pm25   10.0  µg/m³
# 1      1894637  Malkia, Nakuru (DBUSY3473 → ATQJXRNT)      pm25   22.0  µg/m³
# 2      1894637  Malkia, Nakuru (DBUSY3473 → ATQJXRNT)      pm25   21.0  µg/m³
# 3      1894637  Malkia, Nakuru (DBUSY3473 → ATQJXRNT)      pm25   29.0  µg/m³
# 4      1894637  Malkia, Nakuru (DBUSY3473 → ATQJXRNT)      pm25   31.0  µg/m³
#
#                  datetimeUtc        timezone
# 0  2024-02-20T01:00:00+00:00  Africa/Nairobi
# 1  2024-02-20T02:00:00+00:00  Africa/Nairobi
# 2  2024-02-20T03:00:00+00:00  Africa/Nairobi
# 3  2024-02-20T04:00:00+00:00  Africa/Nairobi
# 4  2024-02-20T05:00:00+00:00  Africa/Nairobi

# %%
df_nyayo.head(5)
# Out:
#    location_id            location_name parameter  value   unit  \
# 0      2388059  Nyayo Embakasi, Nairobi       pm1   12.0  µg/m³
# 1      2388059  Nyayo Embakasi, Nairobi       pm1   13.0  µg/m³
# 2      2388059  Nyayo Embakasi, Nairobi       pm1   11.0  µg/m³
# 3      2388059  Nyayo Embakasi, Nairobi       pm1   10.0  µg/m³
# 4      2388059  Nyayo Embakasi, Nairobi       pm1    9.4  µg/m³
#
#                  datetimeUtc        timezone
# 0  2024-03-06T17:00:00+00:00  Africa/Nairobi
# 1  2024-03-06T18:00:00+00:00  Africa/Nairobi
# 2  2024-03-06T19:00:00+00:00  Africa/Nairobi
# 3  2024-03-06T20:00:00+00:00  Africa/Nairobi
# 4  2024-03-06T21:00:00+00:00  Africa/Nairobi

# %%
df_ogada.head(5)
# Out:
#    location_id                                      location_name  \
# 0      1894636  Ogada, Obubra Local Government Area (LGA) → A3...
# 1      1894636  Ogada, Obubra Local Government Area (LGA) → A3...
# 2      1894636  Ogada, Obubra Local Government Area (LGA) → A3...
# 3      1894636  Ogada, Obubra Local Government Area (LGA) → A3...
# 4      1894636  Ogada, Obubra Local Government Area (LGA) → A3...
#
#      parameter  value unit                datetimeUtc      timezone
# 0  temperature   28.0    f  2024-03-09T20:00:00+00:00  Africa/Lagos
# 1  temperature   27.0    f  2024-03-09T21:00:00+00:00  Africa/Lagos
# 2  temperature   26.0    f  2024-03-09T22:00:00+00:00  Africa/Lagos
# 3  temperature   25.0    f  2024-03-09T23:00:00+00:00  Africa/Lagos
# 4  temperature   25.0    f  2024-03-10T00:00:00+00:00  Africa/Lagos

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Duplicate Dropper Function
# A generic function that checks if a dataframe has duplicates. If it has duplicates it drops them.

# %%
def duplicate_dropper(df):
    """
    Checks and drops duplicates in a data frame

    Args:
        df (pandas.DataFrame): The DataFrame containing the data.
    """
    duplicates = df.duplicated()
    for i in duplicates:
        if i == True:
            df.drop_duplicates(inplace=True)
            break

# %% [markdown]
# ### DateTime Converter Function
# A generic function that converts the values in the datetimeUtc column into datetime format.

# %%
def datetime_converter(df):
    """
    Converts column with dates and time into datetime format

    Args:
        df (pandas.DataFrame): The DataFrame containing the data.
    """
    df['datetimeUtc'] = pd.to_datetime(df['datetimeUtc'])

# %% [markdown]
# ### Dropping Duplicates
# Using the generic function all duplicates will be dropped in each of the DataFrames.

# %%
duplicate_dropper(df_lublin)
duplicate_dropper(df_malkia)
duplicate_dropper(df_nyayo)
duplicate_dropper(df_ogada)

# %% [markdown]
# ### Converting to DateTime format
# Using the generic function to convert the column with dates and times into datetime format

# %%
datetime_converter(df_lublin)
datetime_converter(df_malkia)
datetime_converter(df_nyayo)
datetime_converter(df_ogada)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Plotting Box Plot Function
# A generic function that displays a box plot with disaggregation by a categorical variable

# %%
def plot_boxplot(df, x, y, legend=None):
  """
  Plots a box plot of the specified data, optionally displaying actual parameter names on the x-axis.

  Args:
      df (pandas.DataFrame): The DataFrame containing the data.
      x (str): The column name for the x-axis (grouping variable).
      y (str): The column name for the quantitative variable to plot.
      legend (str, optional): The column name containing parameter names (for labeling). Defaults to None.
  """

  plt.figure(figsize=(8, 6))

  plt.boxplot(
      [df[df[x] == group][y] for group in df[x].unique()]
  )
  
  if legend is not None:
      x_labels = df[legend].unique()
      x_labels = [label.upper() for label in x_labels]
      plt.xticks(range(1, len(x_labels) + 1), x_labels)
  else:
      plt.xlabel(x.capitalize())

  plt.ylabel(y.capitalize())
  plt.title(f'Box Plot of {y.capitalize()} by {x.capitalize()}')
  plt.tight_layout()
  plt.show()

# %%
x = 'parameter'
y = 'value'
legend = 'parameter'

# %%
plot_boxplot(df_lublin, x, y, legend)

# %%
plot_boxplot(df_malkia, x, y, legend)

# %%
plot_boxplot(df_nyayo, x, y, legend)

# %%
plot_boxplot(df_ogada, x, y, legend)

# %% [markdown]
# #### Ogada Box Plot Analysis - (Misati)
# The tempearature shows a very normally distributed range of temperature. The same can be said for PM25 save for the fact that there exist a fair number of outliers.
#
# On the other hand PM1 and PM10 show that most of the data aggregates above the mean. This betrays that there was a sudden change in the amount of ambient particles of these size. The extremely skewed distribution has a narrative to tell.

# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# ### Plotting Line Graph Function
# A generic function that draws a line graph with disaggregation by a categorical variable.

# %%
# Misati
x_axis = 'datetimeUtc'
y_axis = 'value'
legend = 'parameter'

colors = ["#626473", "#737162", "#556FF2", "#736C62", "#F2B955", "#3B754B", "#753B5F", "#0E0CF5", "#416275"]
thresholds = {"pm10": 45, "pm25": 25, "o3": 100, "no2": 24, "so2": 40, "co": 7, "pm1": 25}

# %% [markdown]
# #### Lublin Air Quality Line Graph - (Misati)

# %%
data = {}
for param, col_x, col_y in zip(df_lublin[legend], df_lublin[x_axis], df_lublin[y_axis]):
    if not param in data:
        data[param] = []
    data[param].append((col_x, col_y))

fig, axs = plt.subplots(nrows=len(data), ncols=1, figsize=(30, 30))
i = 0
for key, val in data.items():
    axs[i].set_title(key.upper())
    axs[i].plot([xy[0] for xy in val],[xy[1] for xy in val], color=choice(colors))
    i += 1

plt.show()

# %% [markdown]
# #### This is Misati's Understanding Improve on It
# The amount of carbon (I) oxide in the atmosphere at Lublin in Poland peaked from March 8th at 5 PM to March 9th at 8 AM. This aligns with the Hindu festival of Mahashivratri Maha Shivratri which is celebrated on 8th and 9th of March. The amount peaks again to a lesser degree from March 9th at 7 PM to March 10th at 1 AM. During this time, the devotees fast and light sacred fires. Combustion at times when incomplete releases carbon (I) oxide into the atmosphere. As a result, this event affected the amount of CO in the environment. Hence, in Lublin there is a notable Hindu population.
#
# Notwithstanding, soon after the event ended the values of CO stabilised showing that the high CO levels were a seasonal rather than perennial matter. On the other hand, the other indicators of air pollution stay low and consistent. This indicates that Lublin has a solid system that keeps its air clean and pure.

# %% [markdown]
# #### Malkia Air Quality Line Graphs - (Misati)

# %%
data = {}
for param, col_x, col_y in zip(df_malkia[legend], df_malkia[x_axis], df_malkia[y_axis]):
    if not param in data:
        data[param] = []
    data[param].append((col_x, col_y))

fig, axs = plt.subplots(nrows=len(data), ncols=1, figsize=(30, 30))
i = 0
for key, val in data.items():
    if 
    axs[i].set_title(key.upper())
    axs[i].plot([xy[0] for xy in val],[xy[1] for xy in val], color=choice(colors))
    i += 1

plt.show()

# %% [markdown]
# #### Nyayo Air Quality Line Graphs - (Misati)

# %%
data = {}
for param, col_x, col_y in zip(df_nyayo[legend], df_nyayo[x_axis], df_nyayo[y_axis]):
    if not param in data:
        data[param] = []
    data[param].append((col_x, col_y))

fig, axs = plt.subplots(nrows=len(data), ncols=1, figsize=(30, 30))
i = 0
for key, val in data.items():
    axs[i].set_title(key.upper())
    axs[i].plot([xy[0] for xy in val],[xy[1] for xy in val], color=choice(colors))
    i += 1

plt.show()

# %% [markdown]
# #### Ogada Air Quality Line Graphs - (Misati)

# %%
data = {}
for param, col_x, col_y in zip(df_ogada[legend], df_ogada[x_axis], df_ogada[y_axis]):
    if not param in data:
        data[param] = []
    data[param].append((col_x, col_y))

fig, axs = plt.subplots(nrows=len(data), ncols=1, figsize=(30, 30))
i = 0
for key, val in data.items():
    threshold = thresholds.get(key)
    dashed_line_value = thresholds.get(key)
    axs[i].set_title(key.upper())
    axs[i].plot([xy[0] for xy in val],[xy[1] for xy in val], color=choice(colors))
    if threshold:
        axs[i].axhline(threshold, color='black', ls='dotted')
    i += 1

plt.show()

# %% [markdown]
# #### Ogada Line Graphs Analysis - (Misati)

# %% [markdown]
# - For temperature considering that the box plot shows a normal distribution of data points and the line graph displays fluctuations up and down on a roughly balanced basis, it is evident that Ogada experiences balanced temperature conditions.
# - For PM10 and PM1 their graphs are perfectly identical. They start with relatively low amounts of either then rapidly increase to very high levels. On the flip side, PM25 was high when PM1 and PM10 was low. And as PM1 and PM10 rapidly increased PM25 dropped to a near negligible amount. This leads to the possible narrative that the particles in the air were atomised seemingly overnight.
# - Moreover, for each of these particulate matter sizes they are above the allowable 24 hour amount most of the time. This leads to the deduction that the air quality in Ogada is really bad. It is one of the areas that United Nations is targetting to improve.
